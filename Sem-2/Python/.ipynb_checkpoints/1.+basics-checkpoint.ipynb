# %% [markdown]
# This is an *introductory session*

# %% [markdown]
# To get text in italics, enclose it with single underscore or asterisk, to get the text in bold use double underscores or asterisks

# %% [markdown]
#  to get the text in bold use __double underscores or asterisks__

# %% [markdown]
# For header, text should follow by #; more hash signs, smaller the font size. In the following exmaple; in the first line 1 hash, in second line 2 hash and in the third line 3 hash symbols are used.

# %% [markdown]
# # Introductory Session
#
# ## Introduction
#
# ### Session-1

# %%
# PROGRAM - 1

a=3
b=2
c=a+b
print("a= ",a)
print("b= ",b)
print("c= ",c)

# %%
# PROGRAM - 2

x=2
y=5
print (x,y)

# %%
# PROGRAM - 3

# this is a program to explaian the use of division
a=7
b=5
c=a/b
print("c=",c,end='\t')
d=a//b
print("d=",d)
e=b//a
print("e=",e,end=',')
f=a**3 
print("f=",f)
x=7%3
print("x=",x)
# Out:
# c= 1.4	d= 1
# e= 0,f= 343
# x= 1

# %%
# PROGRAM - 4

s1="good"
s2="afternoon"
s3="everyone!"
print(s1,s2,s3)
print(s1,s2,s3,sep="") # by default, sep=" "
print(s1,s2,s3,sep="#")
s4=s1+s2+s3
print(s4)
s5=s1+','+s2+','+s3
print(s5)
s6=s1*4
print(s6)
# Out:
# good afternoon everyone!
# goodafternooneveryone!
# good#afternoon#everyone!
# goodafternooneveryone!
# good,afternoon,everyone!
# goodgoodgoodgood

# %%
# PROGRAM - 5

""" This program demonstrates the way to input the numeric
 and the string values 
s1=input("enter a string:")
print("string s1=",s1)
print(type(s1))
"""
"""
a1=eval(input("enter a number:"))
print("a1=",a1)
print(type(a1))
"""

a2=int(input("enter a number:"))
print("a2=",a2)
print(type(a2))
"""
a3=float(input("enter a number:"))
print("a3=",a3)
print(type(a3))
"""
# Out:
# enter a number:4
# a2= 4
# <class 'int'>
# '\na3=float(input("enter a number:"))\nprint("a3=",a3)\nprint(type(a3))\n'

# %%
s = ('qwery')
