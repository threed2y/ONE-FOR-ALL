# %%
a = 10
b = 15.6
c = 12
d = True
e = "python"
f = "programming"

print(" this is the value of a: ", a)
print(" this is the value of b: ", b)
print(" this is the value of c: ", c)
print(" this is the value of a: ", d)
print(" this is the value of e: ", e)
print(" this is the value of f: ", f)
# Out:
#  this is the value of a:  10
#  this is the value of b:  15.6
#  this is the value of c:  12
#  this is the value of a:  True
#  this is the value of e:  python
#  this is the value of f:  programming

# %%
print(a,b,c, sep="\n")
print(a,b,c, end = "\n")
print(a,b,c)
# Out:
# 10
# 15.6
# 12
# 10 15.6 12
# 10 15.6 12

# %%
print(a*b)
type(a*b)
# Out:
# 156.0
# float

# %%
print(b+f)
type(b+f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 print(b+f)
#       2 type(b+f)
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
print(f+a)
type(f+a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 print(f+a)
#       2 type(f+a)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print(d+f)
type(d+f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 print(d+f)
#       2 type(d+f)
#
# TypeError: unsupported operand type(s) for +: 'bool' and 'str'

# %%
print(b+d+e)
type(b+d+e)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 print(b+d+e)
#       2 type(b+d+e)
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
print(a+c)
type(a+c)
# Out:
# 22
# int

# %%
print(a*c)
type(a*c)
# Out:
# 120
# int

# %%
print(b*c)
type(b*c)
# Out:
# 187.2
# float

# %%
print(a+b)
type(a+b)
# Out:
# 25.6
# float

# %%
print(a+c)
type(a+c)
# Out:
# 22
# int

# %%
print(a**c)
# Out:
# 1000000000000

# %%
print(a+d)
# Out:
# 11

# %%
print(a%d)
# Out:
# 0

# %%
print(a/b)
# Out:
# 0.6410256410256411

# %%
a1 = float(input("your 1st please: "))
a2 = float(input("your 2nd number: "))
a3 = float(input("your 3rd number: "))
a4 = float(input("your 4th number: "))

mean = (a1+a2+a3+a4)/4
var = ((a1**2+a2**2+a3**2+a4**2)/4)-((mean)**2)

print("your numbers are: ", a1,a2,a3,a4)
print("MEAN: ", mean)
print("VARIANCE: ", var)
print("COEFFICIENT OF VARIANCE: ", (var/mean)*100)
# Out:
# your 1st please:  1
# your 2nd number:  2
# your 3rd number:  3
# your 4th number:  4
# your numbers are:  1.0 2.0 3.0 4.0
# MEAN:  2.5
# VARIANCE:  1.25
# COEFFICIENT OF VARIANCE:  50.0
