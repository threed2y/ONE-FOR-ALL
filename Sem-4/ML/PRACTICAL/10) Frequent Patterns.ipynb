# %% [markdown]
# # Frequent Itemset mining
#
# ## Mlxtend package
#
# `mlxtend` (Machine Learning Extensions) is a python library that provides additional utility functions for machine learning tasks. The package can be installed using the following command.
#
#     pip install mlxtend
#
# ### Apriori Algorithm
#
# The `mlxtend` package provides an implementation of Apriori algorithm. The `apriori` function defined in the `frequent_patterns` module implements the apriori algorithm.

# %%
from mlxtend.frequent_patterns import apriori

## Consider a transaction database
dataset = [['Milk', 'Bread', 'Butter', 'Cheese', 'Paneer', 'Curd'],
           ['Barfi', 'Bread', 'Butter', 'Cheese', 'Paneer', 'Curd'],
           ['Milk', 'Peda', 'Cheese', 'Paneer'],
           ['Milk', 'Barfi', 'Peda', 'Cheese', 'Curd'],
           ['Curd', 'Bread', 'Cheese', 'Ice cream', 'Paneer']]

# %% [markdown]
# The `apriori` function requires that the transactions are coded using one-hot encoded
# pandas dataframe. We, therefore, need to transform the dataset into the required format.
#
# This can be achieved using the `TransactionEncoder` class defined in the `preprocessing`
# module of `mlxtend`.

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()  # instantiate TransactionEncoder
te = te.fit(dataset)  # train transaction encoder
CodedDataset = te.transform(dataset)
df = pd.DataFrame(CodedDataset, columns=te.columns_) # transform into DataFrame
df
# Out:
#    Barfi  Bread  Butter  Cheese   Curd  Ice cream   Milk  Paneer   Peda
# 0  False   True    True    True   True      False   True    True  False
# 1   True   True    True    True   True      False  False    True  False
# 2  False  False   False    True  False      False   True    True   True
# 3   True  False   False    True   True      False   True   False   True
# 4  False   True   False    True   True       True  False    True  False

# %% [markdown]
# Observe that the columns of the DataFrame have been arranged in alphabetical order of item names.
#
# Next use `apriori` function to obtain the frequent itemsets.

# %%
FreqSets = apriori(df, min_support=0.6, use_colnames=True)
FreqSets
# Out:
#     support                       itemsets
# 0       0.6                        (Bread)
# 1       1.0                       (Cheese)
# 2       0.8                         (Curd)
# 3       0.6                         (Milk)
# 4       0.8                       (Paneer)
# 5       0.6                (Cheese, Bread)
# 6       0.6                  (Curd, Bread)
# 7       0.6                (Paneer, Bread)
# 8       0.8                 (Curd, Cheese)
# 9       0.6                 (Milk, Cheese)
# 10      0.8               (Cheese, Paneer)
# 11      0.6                 (Curd, Paneer)
# 12      0.6          (Curd, Cheese, Bread)
# 13      0.6        (Paneer, Cheese, Bread)
# 14      0.6          (Paneer, Curd, Bread)
# 15      0.6         (Curd, Cheese, Paneer)
# 16      0.6  (Paneer, Curd, Cheese, Bread)

# %% [markdown]
# Note the use of `use_colnames` parameter supplied to the `apriori` function. By default the value of `use_colnames` parameter is False, and the items are represented in terms of their index in the output as shown below.

# %%
apriori(df, min_support=0.6)
# Out:
#     support      itemsets
# 0       0.6           (1)
# 1       1.0           (3)
# 2       0.8           (4)
# 3       0.6           (6)
# 4       0.8           (7)
# 5       0.6        (1, 3)
# 6       0.6        (1, 4)
# 7       0.6        (1, 7)
# 8       0.8        (3, 4)
# 9       0.6        (3, 6)
# 10      0.8        (3, 7)
# 11      0.6        (4, 7)
# 12      0.6     (1, 3, 4)
# 13      0.6     (1, 3, 7)
# 14      0.6     (1, 4, 7)
# 15      0.6     (3, 4, 7)
# 16      0.6  (1, 3, 4, 7)

# %% [markdown]
# ### Mining Strong Association Rules
#
# Association rules can be mined based on the frequent itemsets that have been mined. This can be achieved using `association_rules` function is module `frequent_patterns`.

# %%
from mlxtend.frequent_patterns import association_rules
association_rules(FreqSets, min_threshold=0.8)
# Out:
#                 antecedents             consequents  antecedent support  \
# 0                   (Bread)                (Cheese)                 0.6
# 1                   (Bread)                  (Curd)                 0.6
# 2                   (Bread)                (Paneer)                 0.6
# 3                    (Curd)                (Cheese)                 0.8
# 4                  (Cheese)                  (Curd)                 1.0
# 5                    (Milk)                (Cheese)                 0.6
# 6                  (Cheese)                (Paneer)                 1.0
# 7                  (Paneer)                (Cheese)                 0.8
# 8             (Curd, Bread)                (Cheese)                 0.6
# 9           (Cheese, Bread)                  (Curd)                 0.6
# 10                  (Bread)          (Curd, Cheese)                 0.6
# 11          (Bread, Paneer)                (Cheese)                 0.6
# 12          (Cheese, Bread)                (Paneer)                 0.6
# 13                  (Bread)        (Cheese, Paneer)                 0.6
# 14           (Curd, Paneer)                 (Bread)                 0.6
# 15          (Bread, Paneer)                  (Curd)                 0.6
# 16            (Curd, Bread)                (Paneer)                 0.6
# 17                  (Bread)          (Curd, Paneer)                 0.6
# 18           (Curd, Paneer)                (Cheese)                 0.6
# 19   (Curd, Cheese, Paneer)                 (Bread)                 0.6
# 20    (Curd, Bread, Paneer)                (Cheese)                 0.6
# 21  (Bread, Cheese, Paneer)                  (Curd)                 0.6
# 22    (Curd, Cheese, Bread)                (Paneer)                 0.6
# 23           (Curd, Paneer)         (Cheese, Bread)                 0.6
# 24          (Bread, Paneer)          (Curd, Cheese)                 0.6
# 25            (Curd, Bread)        (Cheese, Paneer)                 0.6
# 26          (Cheese, Bread)          (Curd, Paneer)                 0.6
# 27                  (Bread)  (Curd, Cheese, Paneer)                 0.6
#
#     consequent support  support  confidence      lift  leverage  conviction
# 0                  1.0      0.6         1.0  1.000000      0.00         inf
# 1                  0.8      0.6         1.0  1.250000      0.12         inf
# 2                  0.8      0.6         1.0  1.250000      0.12         inf
# 3                  1.0      0.8         1.0  1.000000      0.00         inf
# 4                  0.8      0.8         0.8  1.000000      0.00         1.0
# 5                  1.0      0.6         1.0  1.000000      0.00         inf
# 6                  0.8      0.8         0.8  1.000000      0.00         1.0
# 7                  1.0      0.8         1.0  1.000000      0.00         inf
# 8                  1.0      0.6         1.0  1.000000      0.00         inf
# 9                  0.8      0.6         1.0  1.250000      0.12         inf
# 10                 0.8      0.6         1.0  1.250000      0.12         inf
# 11                 1.0      0.6         1.0  1.000000      0.00         inf
# 12                 0.8      0.6         1.0  1.250000      0.12         inf
# 13                 0.8      0.6         1.0  1.250000      0.12         inf
# 14                 0.6      0.6         1.0  1.666667      0.24         inf
# 15                 0.8      0.6         1.0  1.250000      0.12         inf
# 16                 0.8      0.6         1.0  1.250000      0.12         inf
# 17                 0.6      0.6         1.0  1.666667      0.24         inf
# 18                 1.0      0.6         1.0  1.000000      0.00         inf
# 19                 0.6      0.6         1.0  1.666667      0.24         inf
# 20                 1.0      0.6         1.0  1.000000      0.00         inf
# 21                 0.8      0.6         1.0  1.250000      0.12         inf
# 22                 0.8      0.6         1.0  1.250000      0.12         inf
# 23                 0.6      0.6         1.0  1.666667      0.24         inf
# 24                 0.8      0.6         1.0  1.250000      0.12         inf
# 25                 0.8      0.6         1.0  1.250000      0.12         inf
# 26                 0.6      0.6         1.0  1.666667      0.24         inf
# 27                 0.6      0.6         1.0  1.666667      0.24         inf

# %%
int_rules = association_rules(FreqSets, min_threshold=0.8).query('lift > 1').reset_index()
int_rules
# Out:
#     index              antecedents             consequents  \
# 0       1                  (Bread)                  (Curd)
# 1       2                  (Bread)                (Paneer)
# 2       9          (Cheese, Bread)                  (Curd)
# 3      10                  (Bread)          (Curd, Cheese)
# 4      12          (Cheese, Bread)                (Paneer)
# 5      13                  (Bread)        (Cheese, Paneer)
# 6      14           (Curd, Paneer)                 (Bread)
# 7      15          (Bread, Paneer)                  (Curd)
# 8      16            (Curd, Bread)                (Paneer)
# 9      17                  (Bread)          (Curd, Paneer)
# 10     19   (Curd, Cheese, Paneer)                 (Bread)
# 11     21  (Bread, Cheese, Paneer)                  (Curd)
# 12     22    (Curd, Cheese, Bread)                (Paneer)
# 13     23           (Curd, Paneer)         (Cheese, Bread)
# 14     24          (Bread, Paneer)          (Curd, Cheese)
# 15     25            (Curd, Bread)        (Cheese, Paneer)
# 16     26          (Cheese, Bread)          (Curd, Paneer)
# 17     27                  (Bread)  (Curd, Cheese, Paneer)
#
#     antecedent support  consequent support  support  confidence      lift  \
# 0                  0.6                 0.8      0.6         1.0  1.250000
# 1                  0.6                 0.8      0.6         1.0  1.250000
# 2                  0.6                 0.8      0.6         1.0  1.250000
# 3                  0.6                 0.8      0.6         1.0  1.250000
# 4                  0.6                 0.8      0.6         1.0  1.250000
# 5                  0.6                 0.8      0.6         1.0  1.250000
# 6                  0.6                 0.6      0.6         1.0  1.666667
# 7                  0.6                 0.8      0.6         1.0  1.250000
# 8                  0.6                 0.8      0.6         1.0  1.250000
# 9                  0.6                 0.6      0.6         1.0  1.666667
# 10                 0.6                 0.6      0.6         1.0  1.666667
# 11                 0.6                 0.8      0.6         1.0  1.250000
# 12                 0.6                 0.8      0.6         1.0  1.250000
# 13                 0.6                 0.6      0.6         1.0  1.666667
# 14                 0.6                 0.8      0.6         1.0  1.250000
# 15                 0.6                 0.8      0.6         1.0  1.250000
# 16                 0.6                 0.6      0.6         1.0  1.666667
# 17                 0.6                 0.6      0.6         1.0  1.666667
#
#     leverage  conviction
# 0       0.12         inf
# 1       0.12         inf
# 2       0.12         inf
# 3       0.12         inf
# 4       0.12         inf
# 5       0.12         inf
# 6       0.24         inf
# 7       0.12         inf
# 8       0.12         inf
# 9       0.24         inf
# 10      0.24         inf
# 11      0.12         inf
# 12      0.12         inf
# 13      0.24         inf
# 14      0.12         inf
# 15      0.12         inf
# 16      0.24         inf
# 17      0.24         inf

# %% [markdown]
# ### Home Work
# Find out more about the measures **leverage** and **conviction**.
