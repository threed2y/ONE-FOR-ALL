# %% [markdown]
# # Pandas Introduction

# %% [markdown]
# `pandas` is a Python Package that provides a powerful Data analysis and manipulation library
# for Python. It provides
# 1. Data Structures for convenient storage of univariate/multivariate data.
# 2. The tools for manipulating data.
#
# `pandas` is built on top of NumPy.
#
# `pandas` is typically imported as

# %%
import pandas as pd

# %% [markdown]
# `Series` and `DataFrames` are the two important data structures provided by Pandas.

# %%
import numpy as np

# %%
x = [1, 1.2, 1.4, 1.6, 1.8, 2.0]
y = np.random.randn(10)

# %%
x
# Out:
# [1, 1.2, 1.4, 1.6, 1.8, 2.0]

# %%
y
# Out:
# array([-1.23600623, -0.94111523, -0.26536483, -0.52568792,  0.30009324,
#         0.7214413 ,  0.54532709,  0.36939349, -0.32734405, -0.45218398])

# %%
x1 = pd.Series(x)

# %%
x1
# Out:
# 0    1.0
# 1    1.2
# 2    1.4
# 3    1.6
# 4    1.8
# 5    2.0
# dtype: float64

# %%
x2 = pd.Series([2.7, 2.1, 3.2, 2.1, 2.0, 3.2, 3.6])
x2
# Out:
# 0    2.7
# 1    2.1
# 2    3.2
# 3    2.1
# 4    2.0
# 5    3.2
# 6    3.6
# dtype: float64

# %%
x2.values
# Out:
# array([2.7, 2.1, 3.2, 2.1, 2. , 3.2, 3.6])

# %%
type(x2.values)
# Out:
# numpy.ndarray

# %%
x2.size
# Out:
# 7

# %%
x2.index = ['a', 'b', 'c', 'd', 'e', 'f', 'g']

# %%
x2
# Out:
# a    2.7
# b    2.1
# c    3.2
# d    2.1
# e    2.0
# f    3.2
# g    3.6
# dtype: float64

# %%
x3 = pd.Series([10, 15, 13, 18, 11], index = ['A', 'B', 'C', 'D', 'E'])
x3
# Out:
# A    10
# B    15
# C    13
# D    18
# E    11
# dtype: int64

# %%
x3['B':'E']
# Out:
# B    15
# C    13
# D    18
# E    11
# dtype: int64

# %%
x3[1:3]
# Out:
# B    15
# C    13
# dtype: int64

# %%
x3[[0, 2, 4]]
# Out:
# A    10
# C    13
# E    11
# dtype: int64

# %%
x3[x3>=15]
# Out:
# B    15
# D    18
# dtype: int64

# %%
eligible = x3>= 15
x3[eligible]
# Out:
# B    15
# D    18
# dtype: int64

# %%
y1 = pd.Series(y)
y1
# Out:
# 0   -1.236006
# 1   -0.941115
# 2   -0.265365
# 3   -0.525688
# 4    0.300093
# 5    0.721441
# 6    0.545327
# 7    0.369393
# 8   -0.327344
# 9   -0.452184
# dtype: float64

# %%
y1[1]
# Out:
# -0.9411152251824977

# %%
y1[:3]
# Out:
# 0   -1.236006
# 1   -0.941115
# 2   -0.265365
# dtype: float64

# %%
y1[[2, 6, 8]]
# Out:
# 2   -0.265365
# 6    0.545327
# 8   -0.327344
# dtype: float64

# %%
y2 = y1[[2, 6, 2]]
y2
# Out:
# 2   -0.265365
# 6    0.545327
# 2   -0.265365
# dtype: float64

# %%
y2.iloc[1]
# Out:
# 0.5453270879547824

# %%
x4 = pd.Series({'A':34, 'C':38, 'E': 32})
x4
# Out:
# A    34
# C    38
# E    32
# dtype: int64

# %%
x4.loc['A']
# Out:
# 34

# %%
x4.iloc[0]
# Out:
# 34

# %%
x4[0]
# Out:
# 34

# %%
x3
# Out:
# A    10
# B    15
# C    13
# D    18
# E    11
# dtype: int64

# %%
x3 = x3[:3]
x3
# Out:
# A    10
# B    15
# C    13
# dtype: int64

# %%
x4 = pd.Series({'C':34, 'B':38, 'A': 32})
x4
# Out:
# C    34
# B    38
# A    32
# dtype: int64

# %%
x4[0]
# Out:
# 34

# %%
x4*2
# Out:
# C    68
# B    76
# A    64
# dtype: int64

# %%
x5 = pd.Series({'A':14, 'B':18, 'C': 12})
x5
# Out:
# A    14
# B    18
# C    12
# dtype: int64

# %%
x4+x5
# Out:
# A    46
# B    56
# C    46
# dtype: int64

# %%
x3.name = 'Scores'
x3.index.name = 'Player'
x3
# Out:
# Player
# A    10
# B    15
# C    13
# Name: Scores, dtype: int64

# %%
x3[0]
# Out:
# 10

# %%
df1 = pd.DataFrame({'x':x, 'y':y[:6]})

# %%
df1
# Out:
#      x         y
# 0  1.0 -1.236006
# 1  1.2 -0.941115
# 2  1.4 -0.265365
# 3  1.6 -0.525688
# 4  1.8  0.300093
# 5  2.0  0.721441

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df1.columns
# Out:
# Index(['x', 'y'], dtype='object')

# %%
df1.x
# Out:
# 0    1.0
# 1    1.2
# 2    1.4
# 3    1.6
# 4    1.8
# 5    2.0
# Name: x, dtype: float64

# %%
df1['x']
# Out:
# 0    1.0
# 1    1.2
# 2    1.4
# 3    1.6
# 4    1.8
# 5    2.0
# Name: x, dtype: float64

# %%
df1.columns = ['x values', 'y values']
df1
# Out:
#    x values  y values
# 0       1.0 -1.236006
# 1       1.2 -0.941115
# 2       1.4 -0.265365
# 3       1.6 -0.525688
# 4       1.8  0.300093
# 5       2.0  0.721441

# %%
df1.index = ['a', 'b', 'c', 'd', 'e', 'f']

# %%
df1
# Out:
#    x values  y values
# a       1.0 -1.236006
# b       1.2 -0.941115
# c       1.4 -0.265365
# d       1.6 -0.525688
# e       1.8  0.300093
# f       2.0  0.721441

# %%
df1['x values']
# Out:
# a    1.0
# b    1.2
# c    1.4
# d    1.6
# e    1.8
# f    2.0
# Name: x values, dtype: float64

# %%
df1.mean()
# Out:
# x values    1.50000
# y values   -0.32444
# dtype: float64

# %%
df1['id'] = ['i1', 'i2', 'i3', 'i4', 'i5', 'i6']
df1
# Out:
#    x values  y values  id
# a       1.0 -1.236006  i1
# b       1.2 -0.941115  i2
# c       1.4 -0.265365  i3
# d       1.6 -0.525688  i4
# e       1.8  0.300093  i5
# f       2.0  0.721441  i6

# %%
df1.mean()
# Out:
# C:\Users\Vipul\AppData\Local\Temp\ipykernel_9636\2053335143.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.mean()
# x values    1.50000
# y values   -0.32444
# dtype: float64

# %%
df1.std()
# Out:
# C:\Users\Vipul\AppData\Local\Temp\ipykernel_9636\3039516898.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.std()
# x values    0.374166
# y values    0.740154
# dtype: float64

# %%
df1.var()
# Out:
# C:\Users\Vipul\AppData\Local\Temp\ipykernel_9636\2870725145.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.var()
# x values    0.140000
# y values    0.547828
# dtype: float64
