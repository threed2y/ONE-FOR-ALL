# %% [markdown]
# ### vishva patel
# #### Semester-III, M.Sc. (Statistics) Practical Examination
# ##### Data Analysis using Python

# %% [markdown]
# ### Q-3) Write a python code for web scrapping that performs search for a given word on Google and as well as Bing and extracts the number of search results in each case.

# %%
# !pip install beautifulsoup4

# %%
# !pip install google

# %%
try:
    from googlesearch import search
except ImportError:
    print("No module named 'google' found")

# to search
query = "mango tree"

for j in search(query, tld="co.in", num=10, stop=10, pause=2):
    print(j)
# Out:
# https://en.wikipedia.org/wiki/Mangifera_indica
# https://en.wikipedia.org/wiki/Mango
# https://www.britannica.com/plant/mango-plant-and-fruit
# https://www.mango.org/mango-tree/
# https://www.thespruce.com/grow-mango-seeds-1902625
# https://www.gardeningknowhow.com/edible/fruits/mango/growing-mango-trees.htm
# https://www.gardeningknowhow.com/edible/fruits/mango
# https://www.amazon.in/Vamsha-Nature-Care-GRAFTED-Nam-Dok-Mai/dp/B07CK23LTW
# https://www.amazon.in/Plantsguru-Mango-Payari-Grafted-height/dp/B07R99B82G
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-6-ac7514912bae> in <module>
#       7 query = "mango tree"
#       8
# ----> 9 for j in search(query, tld="co.in", num=10, stop=10, pause=2):
#      10     print(j)
#
# ...
