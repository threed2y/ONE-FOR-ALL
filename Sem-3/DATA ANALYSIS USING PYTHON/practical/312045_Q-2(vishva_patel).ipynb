# %% [markdown]
# ### vishva patel
# #### Semester-III, M.Sc. (Statistics) Practical Examination
# ##### Data Analysis using Python

# %% [markdown]
# ### Q-2) The heart dataset comprises of 918 observations on different variables related to heart disease.The variables are described in the data file.

# %% [markdown]
# ##### i)Read this dataset from the file heart.xlsx into a Pandas DataFrame.

# %%
import pandas as pd
import numpy as np

# %%
heart = pd.read_excel('heart.xlsx',header=14)
heart.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %% [markdown]
# ##### ii) Explore the data graphically using tools from seaborn package to identify the variables that influence the maximum heart rate.

# %%
import seaborn as sns

# %%
print(heart.corr())
sns.heatmap(heart.corr(), vmin=-1, vmax=1)
# Out:
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.254399    -0.095282   0.198039 -0.382045  0.258612
# RestingBP     0.254399   1.000000     0.100893   0.070193 -0.112135  0.164803
# Cholesterol  -0.095282   0.100893     1.000000  -0.260974  0.235792  0.050148
# FastingBS     0.198039   0.070193    -0.260974   1.000000 -0.131438  0.052698
# MaxHR        -0.382045  -0.112135     0.235792  -0.131438  1.000000 -0.160691
# Oldpeak       0.258612   0.164803     0.050148   0.052698 -0.160691  1.000000
# HeartDisease  0.282039   0.107589    -0.232741   0.267291 -0.400421  0.403951
#
#               HeartDisease
# Age               0.282039
# RestingBP         0.107589
# Cholesterol      -0.232741
# FastingBS         0.267291
# MaxHR            -0.400421
# Oldpeak           0.403951
# HeartDisease      1.000000
# <AxesSubplot:>

# %% [markdown]
# #### con : as we can see in the colour corresponding to MaxHR then Ageand heart disease are negatively related to MaxHR
