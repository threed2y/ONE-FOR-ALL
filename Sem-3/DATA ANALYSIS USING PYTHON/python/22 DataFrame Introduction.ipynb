# %%
x = [1.1, "2.2",3.3]
y= pd.Series(x)

# %%
y.dtypes
# Out:
# dtype('O')

# %%
import pandas as pd;
import numpy as np;

# %%
x = [1, 1.2, 1.4, 1.6, 1.8, 2.0]
y = np.random.randn(10)

import matplotlib.pyplot as plt
plt.plot(x)

# %%
x
# Out:
# [1, 1.2, 1.4, 1.6, 1.8, 2.0]

# %%
y
# Out:
# array([-2.23501304,  0.48826822,  0.87710316,  1.17733289,  1.15470211,
#         1.07008694, -1.14026867, -1.08190251,  0.91281435,  0.74830564])

# %%
x1 = pd.Series(x)

# %%
x1
# Out:
# 0    1.0
# 1    1.2
# 2    1.4
# 3    1.6
# 4    1.8
# 5    2.0
# dtype: float64

# %%
y1 = pd.Series(y)
y1
# Out:
# 0   -2.235013
# 1    0.488268
# 2    0.877103
# 3    1.177333
# 4    1.154702
# 5    1.070087
# 6   -1.140269
# 7   -1.081903
# 8    0.912814
# 9    0.748306
# dtype: float64

# %%
y[1]
# Out:
# 2.0769471249317486

# %%
y[:3]
# Out:
# array([-1.55888879,  2.07694712, -0.76147609])

# %%
y[[0, 1, 2, 3]]
# Out:
# array([-1.55888879,  2.07694712, -0.76147609,  0.10166093])

# %%
df1 = pd.DataFrame({'x':x, 'y':y[:6]})

# %%
df1
# Out:
#      x         y
# 0  1.0 -1.558889
# 1  1.2  2.076947
# 2  1.4 -0.761476
# 3  1.6  0.101661
# 4  1.8  1.375476
# 5  2.0  1.010992

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df1.columns
# Out:
# Index(['x', 'y'], dtype='object')

# %%
df1.x
# Out:
# 0    1.0
# 1    1.2
# 2    1.4
# 3    1.6
# 4    1.8
# 5    2.0
# Name: x, dtype: float64

# %%
df1['x']
# Out:
# 0    1.0
# 1    1.2
# 2    1.4
# 3    1.6
# 4    1.8
# 5    2.0
# Name: x, dtype: float64

# %%
df1.columns = ['x values', 'y values']
df1
# Out:
#    x values  y values
# 0       1.0 -1.558889
# 1       1.2  2.076947
# 2       1.4 -0.761476
# 3       1.6  0.101661
# 4       1.8  1.375476
# 5       2.0  1.010992

# %%
df1.index = ['a', 'b', 'c', 'd', 'e', 'f']

# %%
df1
# Out:
#    x values  y values
# a       1.0 -1.558889
# b       1.2  2.076947
# c       1.4 -0.761476
# d       1.6  0.101661
# e       1.8  1.375476
# f       2.0  1.010992

# %%
df1['x values']
# Out:
# a    1.0
# b    1.2
# c    1.4
# d    1.6
# e    1.8
# f    2.0
# Name: x values, dtype: float64

# %%
df1.mean()
# Out:
# x values    1.500000
# y values    0.374118
# dtype: float64

# %%
df1['id'] = ['i1', 'i2', 'i3', 'i4', 'i5', 'i6']
df1
# Out:
#    x values  y values  id
# a       1.0 -1.558889  i1
# b       1.2  2.076947  i2
# c       1.4 -0.761476  i3
# d       1.6  0.101661  i4
# e       1.8  1.375476  i5
# f       2.0  1.010992  i6

# %%
df1.mean()
# Out:
# x values    1.500000
# y values    0.374118
# dtype: float64

# %%
df1.std()
# Out:
# x values    0.374166
# y values    1.371734
# dtype: float64

# %%
df1.var()
# Out:
# x values    0.140000
# y values    1.881655
# dtype: float64
