# %% [markdown]
# WRITE A PROGRAM TO TAKE A NUMBER N AS A INPUT AND FIND THE SUM OF FIRST N NATURAL NUMBERS.

# %%
int(input("PLEASE GIVE ME A A NUMBER OF YOUR CHOICE:",n))
n = n(n+1)/2
for n in range (0,n):
    print(" THE SUMMATION OF FIRST n NUMBERS IS : ",c)
else:
    print("CALCULATION ERROR")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 int(input("PLEASE GIVE ME A A NUMBER OF YOUR CHOICE:",n))
#       2 c = n(n+1)/2
#       3 for n in range (0,n):
#
# NameError: name 'n' is not defined
